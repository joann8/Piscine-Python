# %%
from FileLoader import FileLoader
from MyPlotLib import MyPlotLib

# %%
loader = FileLoader()
data = loader.load('../athlete_events.csv')
# Out:
# Loading data set of dimension 271116 x 15

# %%
mpl = MyPlotLib()
features = ['Weight', 'Height', 'Sex']

# %%
mpl.histogram(data, features)
# Out:
# HISTOGRAM: Sex - error data types

# %%
mpl.density(data, features)

# %%
mpl.pair_plot(data, features)

# %%
mpl.box_plot(data, features)
